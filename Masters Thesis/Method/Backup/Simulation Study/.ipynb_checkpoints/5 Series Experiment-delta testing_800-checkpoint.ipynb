# %%
import pandas as pd
import numpy as np
import my_functions as mf
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.vector_ar.vecm import coint_johansen
np.random.seed(22)

T_list = []
num_series_list = []
coint_frac_list = []
num_of_rw_list = []
SADF_list = []
crit_95_list = []
crit_99_list = []
delta_list = []

# %%
z = mf.random_walk(1000).reshape(-1, 1) #constant
eps = np.random.normal(0, 1, size=(1000, 5)) # DEPENDS on T
et = np.random.normal(0, 1, size=(1000, 5)) #constant
num_series = 5
B = 2500

multipliers = mf.unique_rounded_uniform(1, 2, num_series, decimals=1) #constant

# %%
plt.figure(figsize=(15, 3))
plt.plot(z, color = "darkorange")
plt.title("Common Factor")
plt.show()

# %%
num_of_rw = 0.6
T = 800
e = eps[:T,:].copy()
common_fac = z[:T].copy()
coint_frac = 0.4
innov_6 = np.random.normal(0, 1, size=(T - int(T * coint_frac), int(num_of_rw * num_series))) #constant

# %%
crit_val = mf.simulate_sadf_distribution(B=B, T=T, num_series=num_series, coint_frac=coint_frac, num_of_rw=num_of_rw, multi = multipliers)
print(crit_val)
crit_val_95 =  np.round(crit_val.loc["95%", "Critical Value"],3)
crit_val_99 =  np.round(crit_val.loc["99%", "Critical Value"],3)
# Out:
# Running Simulations: |██████████████████████████████| 100% --- 2500/2500
#      Critical Value
# 90%        2.538739
# 95%        3.062141
# 99%        3.905576

# %% [markdown]
# ## Positive

# %%
innov = np.random.normal(0, 1, size=(T - int(T * coint_frac), int(num_of_rw * num_series))) #constant

# %%
delta = 0.01
""" Run Experiment """
sadf_val = mf.run_sadf_bubble_check( delta, T, coint_frac, num_of_rw,  common_fac, multipliers, innov, e, crit_val_95, crit_val_99, num_series)
print("Multipliers:", multipliers)

T_list.append(T)
num_series_list.append(num_series)
coint_frac_list.append(coint_frac)
num_of_rw_list.append(num_of_rw)
SADF_list.append(sadf_val)
crit_95_list.append(crit_val_95)
crit_99_list.append(crit_val_99)
delta_list.append(delta)
# Out:
# beta =  [0.17208621 0.1319545  0.13525253 0.22643686]
# alpha =  -0.061
# ADF on residuals  stat = -6.535
# Time series is Explosive. SADF Value is: 20.22
#
# Bubble starts at t=517
# Multipliers: [1.1 1.7 1.6 1.3 1.9]

# %%
delta = 0.012
sadf_val = mf.run_sadf_bubble_check( delta, T, coint_frac, num_of_rw,  common_fac, multipliers, innov, e, crit_val_95, crit_val_99, num_series)
print("Multipliers:", multipliers)

T_list.append(T)
num_series_list.append(num_series)
coint_frac_list.append(coint_frac)
num_of_rw_list.append(num_of_rw)
SADF_list.append(sadf_val)
crit_95_list.append(crit_val_95)
crit_99_list.append(crit_val_99)
delta_list.append(delta)
# Out:
# beta =  [0.17208621 0.1319545  0.13525253 0.22643686]
# alpha =  -0.061
# ADF on residuals  stat = -6.535
# Time series is Explosive. SADF Value is: 23.69
#
# Bubble starts at t=495
# Multipliers: [1.1 1.7 1.6 1.3 1.9]

# %%
delta = 0.0125
""" Run Experiment """
sadf_val = mf.run_sadf_bubble_check( delta, T, coint_frac, num_of_rw,  common_fac, multipliers, innov, e, crit_val_95, crit_val_99, num_series)
print("Multipliers:", multipliers)

T_list.append(T)
num_series_list.append(num_series)
coint_frac_list.append(coint_frac)
num_of_rw_list.append(num_of_rw)
SADF_list.append(sadf_val)
crit_95_list.append(crit_val_95)
crit_99_list.append(crit_val_99)
delta_list.append(delta)
# Out:
# beta =  [0.17208621 0.1319545  0.13525253 0.22643686]
# alpha =  -0.061
# ADF on residuals  stat = -6.535
# Time series is Explosive. SADF Value is: 23.99
#
# Bubble starts at t=475
# Multipliers: [1.1 1.7 1.6 1.3 1.9]

# %%
delta = 0.013
sadf_val = mf.run_sadf_bubble_check( delta, T, coint_frac, num_of_rw,  common_fac, multipliers, innov, e, crit_val_95, crit_val_99, num_series)
print("Multipliers:", multipliers)

T_list.append(T)
num_series_list.append(num_series)
coint_frac_list.append(coint_frac)
num_of_rw_list.append(num_of_rw)
SADF_list.append(sadf_val)
crit_95_list.append(crit_val_95)
crit_99_list.append(crit_val_99)
delta_list.append(delta)
# Out:
# beta =  [0.17208621 0.1319545  0.13525253 0.22643686]
# alpha =  -0.061
# ADF on residuals  stat = -6.535
# Time series is Explosive. SADF Value is: 24.18
#
# Bubble starts at t=469
# Multipliers: [1.1 1.7 1.6 1.3 1.9]

# %%
delta = 0.015
""" Run Experiment """
sadf_val = mf.run_sadf_bubble_check( delta, T, coint_frac, num_of_rw,  common_fac, multipliers, innov, e, crit_val_95, crit_val_99, num_series)
print("Multipliers:", multipliers)

T_list.append(T)
num_series_list.append(num_series)
coint_frac_list.append(coint_frac)
num_of_rw_list.append(num_of_rw)
SADF_list.append(sadf_val)
crit_95_list.append(crit_val_95)
crit_99_list.append(crit_val_99)
delta_list.append(delta)
# Out:
# beta =  [0.17208621 0.1319545  0.13525253 0.22643686]
# alpha =  -0.061
# ADF on residuals  stat = -6.535
# Time series is Explosive. SADF Value is: 24.39
#
# Bubble starts at t=435
# Multipliers: [1.1 1.7 1.6 1.3 1.9]

# %%
delta = 0.02
""" Run Experiment """
sadf_val = mf.run_sadf_bubble_check( delta, T, coint_frac, num_of_rw,  common_fac, multipliers, innov, e, crit_val_95, crit_val_99, num_series)
print("Multipliers:", multipliers)

T_list.append(T)
num_series_list.append(num_series)
coint_frac_list.append(coint_frac)
num_of_rw_list.append(num_of_rw)
SADF_list.append(sadf_val)
crit_95_list.append(crit_val_95)
crit_99_list.append(crit_val_99)
delta_list.append(delta)
# Out:
# beta =  [0.17208621 0.1319545  0.13525253 0.22643686]
# alpha =  -0.061
# ADF on residuals  stat = -6.535
# Time series is Explosive. SADF Value is: 24.23
#
# Bubble starts at t=383
# Multipliers: [1.1 1.7 1.6 1.3 1.9]

# %% [markdown]
# ## Negative

# %%
delta = 0.008
""" Run Experiment """
sadf_val = mf.run_sadf_bubble_check( delta, T, coint_frac, num_of_rw,  common_fac, multipliers, innov, e, crit_val_95, crit_val_99, num_series)
print("Multipliers:", multipliers)

T_list.append(T)
num_series_list.append(num_series)
coint_frac_list.append(coint_frac)
num_of_rw_list.append(num_of_rw)
SADF_list.append(sadf_val)
crit_95_list.append(crit_val_95)
crit_99_list.append(crit_val_99)
delta_list.append(delta)
# Out:
# beta =  [0.17208621 0.1319545  0.13525253 0.22643686]
# alpha =  -0.061
# ADF on residuals  stat = -6.535
# Time series is Explosive. SADF Value is: 12.53
#
# Bubble starts at t=574
# Multipliers: [1.1 1.7 1.6 1.3 1.9]

# %%
delta = 0.0075
""" Run Experiment """
sadf_val = mf.run_sadf_bubble_check( delta, T, coint_frac, num_of_rw,  common_fac, multipliers, innov, e, crit_val_95, crit_val_99, num_series)
print("Multipliers:", multipliers)

T_list.append(T)
num_series_list.append(num_series)
coint_frac_list.append(coint_frac)
num_of_rw_list.append(num_of_rw)
SADF_list.append(sadf_val)
crit_95_list.append(crit_val_95)
crit_99_list.append(crit_val_99)
delta_list.append(delta)
# Out:
# beta =  [0.17208621 0.1319545  0.13525253 0.22643686]
# alpha =  -0.061
# ADF on residuals  stat = -6.535
# Time series is Explosive. SADF Value is: 10.67
#
# Bubble starts at t=591
# Multipliers: [1.1 1.7 1.6 1.3 1.9]

# %%
delta = 0.007
""" Run Experiment """
sadf_val = mf.run_sadf_bubble_check( delta, T, coint_frac, num_of_rw,  common_fac, multipliers, innov, e, crit_val_95, crit_val_99, num_series)
print("Multipliers:", multipliers)

T_list.append(T)
num_series_list.append(num_series)
coint_frac_list.append(coint_frac)
num_of_rw_list.append(num_of_rw)
SADF_list.append(sadf_val)
crit_95_list.append(crit_val_95)
crit_99_list.append(crit_val_99)
delta_list.append(delta)
# Out:
# beta =  [0.17208621 0.1319545  0.13525253 0.22643686]
# alpha =  -0.061
# ADF on residuals  stat = -6.535
# Time series is Explosive. SADF Value is: 9.02
#
# Bubble starts at t=605
# Multipliers: [1.1 1.7 1.6 1.3 1.9]

# %%
delta = 0.005
""" Run Experiment """
sadf_val = mf.run_sadf_bubble_check( delta, T, coint_frac, num_of_rw,  common_fac, multipliers, innov, e, crit_val_95, crit_val_99, num_series)
print("Multipliers:", multipliers)

T_list.append(T)
num_series_list.append(num_series)
coint_frac_list.append(coint_frac)
num_of_rw_list.append(num_of_rw)
SADF_list.append(sadf_val)
crit_95_list.append(crit_val_95)
crit_99_list.append(crit_val_99)
delta_list.append(delta)
# Out:
# beta =  [0.17208621 0.1319545  0.13525253 0.22643686]
# alpha =  -0.061
# ADF on residuals  stat = -6.535
# Time series is Explosive. SADF Value is: 4.41
#
# Bubble starts at t=717
# Multipliers: [1.1 1.7 1.6 1.3 1.9]

# %%
delta = 0.001
""" Run Experiment """
sadf_val = mf.run_sadf_bubble_check( delta, T, coint_frac, num_of_rw,  common_fac, multipliers, innov, e, crit_val_95, crit_val_99, num_series)
print("Multipliers:", multipliers)

T_list.append(T)
num_series_list.append(num_series)
coint_frac_list.append(coint_frac)
num_of_rw_list.append(num_of_rw)
SADF_list.append(sadf_val)
crit_95_list.append(crit_val_95)
crit_99_list.append(crit_val_99)
delta_list.append(delta)
# Out:
# beta =  [0.17208621 0.1319545  0.13525253 0.22643686]
# alpha =  -0.061
# ADF on residuals  stat = -6.535
# Time series is Non Explosive. SADF Value is: 0.53
#
# Multipliers: [1.1 1.7 1.6 1.3 1.9]

# %%
pd.DataFrame({
    'T': T_list,
    'num_series': num_series_list,
    'coint_frac': coint_frac_list,
    'num_of_rw': num_of_rw_list,
    'SADF': SADF_list,
    'crit_95': crit_95_list,
    'crit_99': crit_99_list,
    'delta':delta_list
}).to_csv(str(num_series) + "_Series_Experiment_Delta_testing_800.csv", index=False)

import sounddevice as sd
fs = 70100  # sample rate
t = np.linspace(0, 2, fs, False)             # 1 second
sd.play(np.sin(2 * np.pi * 440 * t) * 0.5, fs)  # 440 Hz at half volume
sd.wait()
np.random.seed(22)
