# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Question 1)

# %% [markdown]
# The first question of the assignment asks to explain the roles of \( \alpha_g \), \( \beta_g \), and \( \delta_g \) in the Google Ads adstock model:\\
# $
# gadst = \frac{\alpha_g \cdot g_t}{1 + \delta_g \cdot gadst_{-1}} + \beta_g \cdot gadst_{-1},]
# $
# and how they relate to the decay effect and diminishing returns.
#
# 1. **Role of \( \alpha_g \)**: This parameter represents the effectiveness of current advertising expenditure in generating adstock. Higher \( \alpha_g \) values indicate that each unit of expenditure has a stronger immediate impact on adstock. It directly scales the advertising input (\( g_t \)) and adjusts the initial level of consumer awareness or response to the ad.
#
# 2. **Role of \( \beta_g \)**: The \( \beta_g \) parameter captures the persistence of adstock over time, reflecting the "decay effect." A higher \( \beta_g \) implies a slower decay of the adstock, meaning the effects of past advertising linger longer. It determines how much of the previous period's adstock (\( gadst_{-1} \)) carries over into the current period.
#
# 3. **Role of \( \delta_g \)**: This parameter addresses the diminishing returns of advertising. As the previous adstock (\( gadst_{-1} \)) increases, the impact of additional advertising is reduced. A larger \( \delta_g \) value means a steeper reduction in marginal returns, indicating that higher past adstock levels make current advertising less effective in generating new awareness.
#
# Together, these parameters allow the model to capture both the persistence of advertising effects (through \( \beta_g \)) and the diminishing impact of repeated advertising exposure (through \( \delta_g \)), while scaling the overall impact via \( \alpha_g \).

# %% [markdown]
# ### Question 2)

# %%
data = pd.read_csv(r"C:\Users\archi\OneDrive\Desktop\VU\My VU\P1\Adv Econ\Assignment GA - 3\Solara_AB_data.csv",   parse_dates=["dates"])

# %%
data
# Out:
#           dates            s           g           y
# 0    01/01/2024  4260.478186  220.873050  217.988012
# 1    02/01/2024  4392.088417  210.723291  188.028484
# 2    03/01/2024  3573.676586  151.117026  249.976529
# 3    04/01/2024  3245.750115  188.584675  289.264673
# 4    05/01/2024  3173.069842  201.874913  212.419362
# ..          ...          ...         ...         ...
# 177  26/06/2024  4127.146979  369.568625  180.182805
# 178  27/06/2024  4059.608612  212.325771  202.929193
# 179  28/06/2024  4363.794171  279.291311  220.037644
# 180  29/06/2024  3682.737757  165.258469  202.025129
# 181  30/06/2024  3465.241311  202.753394  379.689497
#
# [182 rows x 4 columns]

# %%
g_params = [2,0.9,10]
y_params = [1,0.97,5]

# %%
data['gads'] = np.ones((len(data),1))
data['yads'] = np.ones((len(data),1))
data.loc[0, 'gads'] = 22
data.loc[0, 'yads'] = 41

# %%
data
# Out:
#           dates            s           g           y  gads  yads
# 0    01/01/2024  4260.478186  220.873050  217.988012  22.0  41.0
# 1    02/01/2024  4392.088417  210.723291  188.028484   1.0   1.0
# 2    03/01/2024  3573.676586  151.117026  249.976529   1.0   1.0
# 3    04/01/2024  3245.750115  188.584675  289.264673   1.0   1.0
# 4    05/01/2024  3173.069842  201.874913  212.419362   1.0   1.0
# ..          ...          ...         ...         ...   ...   ...
# 177  26/06/2024  4127.146979  369.568625  180.182805   1.0   1.0
# 178  27/06/2024  4059.608612  212.325771  202.929193   1.0   1.0
# 179  28/06/2024  4363.794171  279.291311  220.037644   1.0   1.0
# 180  29/06/2024  3682.737757  165.258469  202.025129   1.0   1.0
# 181  30/06/2024  3465.241311  202.753394  379.689497   1.0   1.0
#
# [182 rows x 6 columns]

# %%
for i in range(1,len(data)):
    data.loc[i, 'gads'] = ((g_params[0]*data.loc[i, 'g'])/(1+g_params[2]*data.loc[i-1, 'gads'])) + (g_params[1]*data.loc[i-1, 'gads'])

    data.loc[i, 'yads'] = ((y_params[0]*data.loc[i, 'y'])/(1+y_params[2]*data.loc[i-1, 'yads'])) + (y_params[1]*data.loc[i-1, 'yads'])

# %%
data
# Out:
#           dates            s           g           y       gads       yads
# 0    01/01/2024  4260.478186  220.873050  217.988012  22.000000  41.000000
# 1    02/01/2024  4392.088417  210.723291  188.028484  21.706998  40.682760
# 2    03/01/2024  3573.676586  151.117026  249.976529  20.922248  40.685171
# 3    04/01/2024  3245.750115  188.584675  289.264673  20.624167  40.879626
# 4    05/01/2024  3173.069842  201.874913  212.419362  20.509958  40.687421
# ..          ...          ...         ...         ...        ...        ...
# 177  26/06/2024  4127.146979  369.568625  180.182805  23.836520  40.718734
# 178  27/06/2024  4059.608612  212.325771  202.929193  23.226941  40.489036
# 179  28/06/2024  4363.794171  279.291311  220.037644  23.298829  40.355923
# 180  29/06/2024  3682.737757  165.258469  202.025129  22.381482  40.141524
# 181  30/06/2024  3465.241311  202.753394  379.689497  21.947071  40.819654
#
# [182 rows x 6 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Convert the 'dates' column to datetime
data['dates'] = pd.to_datetime(data['dates'], format='%d/%m/%Y')

# Create a 2x2 grid of plots with a different color scheme
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# Set background color to gray for each subplot
for ax in axs.flat:
    ax.set_facecolor('lightgray')

# Plot the filtered Google adstock (time series) using green color
axs[0, 0].plot(data['dates'], data['gads'], label='Filtered Google Adstock', color='green')
axs[0, 0].set_title('Filtered Google Adstock Over Time')
axs[0, 0].set_xlabel('Date')
axs[0, 0].set_ylabel('Adstock Level')
axs[0, 0].legend()
axs[0, 0].xaxis.set_major_locator(mdates.MonthLocator())  # Set major ticks to monthly
axs[0, 0].xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))  # Format date as 'Month Year'

# Plot the histogram for Google adstock using teal color
axs[0, 1].hist(data['gads'], bins=50, color='green', alpha=0.7)
axs[0, 1].set_title('Histogram of Filtered Google Adstock')
axs[0, 1].set_xlabel('Adstock Level')
axs[0, 1].set_ylabel('Frequency')

# Plot the filtered YouTube adstock (time series) using purple color
axs[1, 0].plot(data['dates'], data['yads'], label='Filtered YouTube Adstock', color='maroon')
axs[1, 0].set_title('Filtered YouTube Adstock Over Time')
axs[1, 0].set_xlabel('Date')
axs[1, 0].set_ylabel('Adstock Level')
axs[1, 0].legend()
axs[1, 0].xaxis.set_major_locator(mdates.MonthLocator())  # Set major ticks to monthly
axs[1, 0].xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))  # Format date as 'Month Year'

# Plot the histogram for YouTube adstock using orange color
axs[1, 1].hist(data['yads'], bins=50, color='maroon', alpha=0.7)
axs[1, 1].set_title('Histogram of Filtered YouTube Adstock')
axs[1, 1].set_xlabel('Adstock Level')
axs[1, 1].set_ylabel('Frequency')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# Certainly! Let's analyze the filtered adstocks for Google and YouTube in the context of Solara's marketing efforts and the case study's objectives:
#
# ### Case Study Context:
# Solara is trying to understand the effects of its advertising expenditures on Google and YouTube to optimize marketing strategies for selling single-trip travel insurance. The company aims to analyze how adstock, which captures the residual impact of past advertising, behaves over time to improve campaign effectiveness.
#
# ### Analysis of Filtered Adstocks:
#
# 1. **Time Series Patterns**:
#    - **Google Adstock**:
#      - The filtered Google adstock fluctuates between approximately 19 and 24. This indicates that the impact of advertising on Google is somewhat stable but subject to periods of sharp drops and gradual recoveries. These fluctuations may reflect changes in consumer engagement with Google ads, possibly driven by factors like ad fatigue or varying levels of ad content relevance.
#      - The noticeable peaks and troughs suggest that while certain ad campaigns may have initially boosted consumer awareness, the adstock decay (remembering effect) happens relatively quickly. This may indicate that the incremental gains from increased Google ad spending diminish over time, as expected with the law of diminishing returns.
#    - **YouTube Adstock**:
#      - The filtered YouTube adstock fluctuates in a broader range (approximately 38 to 44), indicating higher volatility in ad effectiveness. This could imply that YouTube's audience exhibits varying engagement levels based on the type of content or timing of the ads.
#      - The more pronounced swings in YouTube adstock may suggest that some campaigns resonate more strongly with consumers (leading to rapid increases in adstock), while others quickly lose their impact. This variability could point to a need for better-targeted YouTube ads or a refined content strategy to sustain consumer attention.
#
# 2. **Histograms and Skewness**:
#    - **Google Adstock**:
#      - The histogram shows a right-skewed distribution, with most adstock values clustered around 21-23. This skewness suggests that the adstock for Google tends to maintain a baseline level of impact, but occasionally experiences higher-than-normal effects. These bursts may occur due to particularly successful campaigns or well-timed ads.
#      - The presence of fewer instances at lower adstock levels indicates that once consumer awareness is generated through Google Ads, it does not decay to a minimal level frequently. This implies a moderate degree of persistence in consumer memory from Google campaigns.
#    - **YouTube Adstock**:
#      - The histogram for YouTube adstock is more symmetric, with a central peak around 40-41. This suggests that the adstock is more evenly distributed across its range, pointing to frequent changes in the ad's effectiveness. The symmetric pattern indicates that the impact of YouTube advertising is more transient, with the decay effect and ad refresh cycles balancing out over time.
#      - The broader range of the histogram supports the idea that YouTube ad effectiveness is more variable, potentially due to different content types, audience preferences, or seasonal factors affecting engagement.
#
# ### Implications for Solara's Marketing Strategy:
# - **Google Ads**:
#   - The relative stability in Google adstock suggests that consistent investment in Google Ads can maintain a steady level of consumer awareness. However, the diminishing returns observed in the data indicate that Solara should consider optimizing the ad budget to prevent overspending in periods where incremental gains are minimal.
#   - Solara could explore strategies to prolong the adstock effect, such as using more engaging ad formats or retargeting ads to users who have previously shown interest.
#
# - **YouTube Ads**:
#   - The higher volatility and broader range of YouTube adstock imply that Solara's campaigns may benefit from more precise targeting or content personalization to increase engagement. Since YouTube adstock is more prone to rapid changes, Solara could experiment with shorter ad cycles or continuously refreshed content to sustain consumer interest.
#   - Additionally, the company could analyze the performance of different ad formats (e.g., skippable vs. non-skippable ads) to identify which strategies yield the most durable adstock effects.
#
# ### Conclusion:
# The filtered adstock analysis reveals that while Google Ads tend to maintain a more stable effect with occasional higher impacts, YouTube Ads experience more variability, suggesting different approaches for optimizing advertising strategies on these platforms. By tailoring ad spending and content strategies to the distinct characteristics of each platform's adstock behavior, Solara can improve the effectiveness of its marketing campaigns and achieve better sales outcomes for its travel insurance products.

# %% [markdown]
# #### Question 3)

# %%
import statsmodels.api as sm

X = data[['gads', 'yads']]
X = sm.add_constant(X)
y = data['s']

model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      s   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.910
# Method:                 Least Squares   F-statistic:                     911.4
# Date:                Thu, 10 Oct 2024   Prob (F-statistic):           1.43e-94
# Time:                        16:43:10   Log-Likelihood:                -1246.5
# No. Observations:                 182   AIC:                             2499.
# Df Residuals:                     179   BIC:                             2509.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.707e+04    844.719    -32.048      0.000   -2.87e+04   -2.54e+04
# ...

# %% [markdown]
# ### Interpretation of the Estimates:
#
# 1. **Intercept (\( \mu \))**:
#    - The estimated intercept was approximately -2707.84. In the context of this model, the intercept represents the baseline level of sales when both Google and YouTube adstocks are zero. Although a negative intercept is not meaningful in a real-world scenario, it indicates that without any ad impact, Solara’s baseline sales would be low, emphasizing the importance of advertising in generating sales.
#
# 2. **Google Adstock Coefficient (\( \phi_g \approx 420.30 \))**:
#    - This coefficient indicates that for each additional unit increase in the filtered Google adstock, Solara's sales increase by approximately 420.30 units, holding the YouTube adstock constant.
#    - **Case Study Context**: This finding implies that Google advertising has a substantial and statistically significant impact on driving sales. If Solara increases its Google ad effectiveness or retains ad impact over time (higher adstock), it can expect a significant boost in sales. This suggests that optimizing the ad content or increasing the frequency of effective Google ads could be beneficial for boosting travel insurance sales.
#
# 3. **YouTube Adstock Coefficient (\( \phi_y \approx 527.68 \))**:
#    - This coefficient suggests that for each additional unit increase in the filtered YouTube adstock, sales are expected to increase by approximately 527.68 units, holding the Google adstock constant.
#    - **Case Study Context**: The larger magnitude of \( \phi_y \) compared to \( \phi_g \) suggests that YouTube advertising is more impactful than Google advertising for Solara's target audience. This could be due to the visual nature of YouTube ads, which might resonate more with potential customers looking for travel insurance. This finding indicates that Solara should consider investing more in YouTube advertising or fine-tuning its YouTube ad strategies to maximize sales.
#
# ### Implications for Solara’s Marketing Strategy:
# - The positive and significant coefficients for both \( \phi_g \) and \( \phi_y \) suggest that digital advertising on Google and YouTube has a strong impact on sales, confirming the importance of maintaining an effective online marketing presence.
# - Since the coefficient for YouTube is larger, it may be more cost-effective for Solara to focus a higher portion of its budget on YouTube ads, as they appear to generate a greater increase in sales compared to Google ads.
# - However, both platforms show significant impact, indicating that a balanced strategy involving both Google and YouTube can maximize reach and sales. Solara should explore methods to enhance ad retention (higher adstock) on both platforms, such as retargeting campaigns or using a mix of ad formats.
#
# ### Assumptions:
# This interpretation assumes that the model is correctly specified, meaning that all relevant factors influencing sales are captured by the model and the relationship between sales, Google adstock, and YouTube adstock is appropriately linear. Given the high R-squared value (0.911), the model appears to explain a large proportion of the variance in sales, suggesting that advertising is indeed a key driver of sales for Solara.
#
# In conclusion, the regression results provide valuable insights for Solara to optimize its marketing strategy, with a particular emphasis on leveraging the higher impact of YouTube advertising while also maintaining a strong presence on Google.

# %% [markdown]
# #### Question 4)

# %% [markdown]
# Let's solve Question 4 using the provided parameters and the hint given in the question.
#
# ### Given Parameters:
# - For Google Ads: \( \hat{\alpha}_g = 2 \), \( \hat{\beta}_g = 0.9 \), \( \hat{\delta}_g = 10 \)
# - For YouTube Ads: \( \hat{\alpha}_y = 1 \), \( \hat{\beta}_y = 0.97 \), \( \hat{\delta}_y = 5 \)
#
# The daily fixed budget is 250 euros for each platform.
#
# ### Google Adstock Long-Run Solution:
# We start with the equation for the long-run adstock \( gads_\infty \):
# \[
# gads_\infty = \frac{\hat{\alpha}_g \cdot 250}{1 + \hat{\delta}_g \cdot gads_\infty} + \hat{\beta}_g \cdot gads_\infty.
# \]
#
# ### Step 1: Substitute the Parameters
# Substitute the given values for \( \hat{\alpha}_g \), \( \hat{\beta}_g \), and \( \hat{\delta}_g \):
# \[
# gads_\infty = \frac{2 \cdot 250}{1 + 10 \cdot gads_\infty} + 0.9 \cdot gads_\infty.
# \]
#
# ### Step 2: Rearrange the Equation
# Move the term involving \( 0.9 \cdot gads_\infty \) to the left:
# \[
# gads_\infty - 0.9 \cdot gads_\infty = \frac{500}{1 + 10 \cdot gads_\infty}.
# \]
# This simplifies to:
# \[
# 0.1 \cdot gads_\infty = \frac{500}{1 + 10 \cdot gads_\infty}.
# \]
#
# ### Step 3: Cross-Multiply
# Multiply both sides by \( 1 + 10 \cdot gads_\infty \) to eliminate the denominator:
# \[
# 0.1 \cdot gads_\infty \cdot (1 + 10 \cdot gads_\infty) = 500.
# \]
# Expand the left side:
# \[
# 0.1 \cdot gads_\infty + gads_\infty^2 = 500.
# \]
#
# ### Step 4: Solve the Quadratic Equation
# Rewrite the equation as:
# \[
# gads_\infty^2 + 0.1 \cdot gads_\infty - 500 = 0.
# \]
# Use the quadratic formula:
# \[
# gads_\infty = \frac{-B \pm \sqrt{B^2 - 4AC}}{2A},
# \]
# where \( A = 1 \), \( B = 0.1 \), and \( C = -500 \).
#
# ### Step 5: Calculate the Solution
# Plug in the values:
# \[
# gads_\infty = \frac{-0.1 \pm \sqrt{(0.1)^2 - 4 \cdot 1 \cdot (-500)}}{2 \cdot 1}.
# \]
# \[
# gads_\infty = \frac{-0.1 \pm \sqrt{0.01 + 2000}}{2}.
# \]
# \[
# gads_\infty = \frac{-0.1 \pm \sqrt{2000.01}}{2}.
# \]
# \[
# gads_\infty = \frac{-0.1 \pm 44.72}{2}.
# \]
#
# The two solutions are:
# \[
# gads_\infty = \frac{44.62}{2} \approx 22.31 \quad \text{(positive solution, feasible)},
# \]
# \[
# gads_\infty = \frac{-44.82}{2} \approx -22.41 \quad \text{(negative solution, not feasible)}.
# \]
#
# So, the long-run adstock for Google Ads is approximately **22.31**.
#
# ### YouTube Adstock Long-Run Solution:
# Repeat the same process using \( \hat{\alpha}_y = 1 \), \( \hat{\beta}_y = 0.97 \), and \( \hat{\delta}_y = 5 \):
# \[
# yads_\infty = \frac{1 \cdot 250}{1 + 5 \cdot yads_\infty} + 0.97 \cdot yads_\infty.
# \]
#
# Following the same steps:
# 1. Rearrange to get:
#    \[
#    0.03 \cdot yads_\infty = \frac{250}{1 + 5 \cdot yads_\infty}.
#    \]
# 2. Cross-multiply:
#    \[
#    0.03 \cdot yads_\infty \cdot (1 + 5 \cdot yads_\infty) = 250.
#    \]
#    Expand:
#    \[
#    0.03 \cdot yads_\infty + 0.15 \cdot yads_\infty^2 = 250.
#    \]
# 3. Rewrite as a quadratic equation:
#    \[
#    0.15 \cdot yads_\infty^2 + 0.03 \cdot yads_\infty - 250 = 0.
#    \]
# 4. Solve using the quadratic formula:
#    - \( A = 0.15 \), \( B = 0.03 \), \( C = -250 \).
#    - Calculate:
#      \[
#      yads_\infty = \frac{-0.03 \pm \sqrt{(0.03)^2 - 4 \cdot 0.15 \cdot (-250)}}{2 \cdot 0.15}.
#      \]
#      \[
#      yads_\infty = \frac{-0.03 \pm \sqrt{0.0009 + 150}}{0.3}.
#      \]
#      \[
#      yads_\infty = \frac{-0.03 \pm \sqrt{150.0009}}{0.3}.
#      \]
#      \[
#      yads_\infty = \frac{-0.03 \pm 12.247}{0.3}.
#      \]
#
# The two solutions are:
# \[
# yads_\infty = \frac{12.217}{0.3} \approx 40.72 \quad \text{(positive solution, feasible)},
# \]
# \[
# yads_\infty = \frac{-12.277}{0.3} \approx -40.92 \quad \text{(negative solution, not feasible)}.
# \]
#
# So, the long-run adstock for YouTube Ads is approximately **40.72**.
#
# ### Conclusion:
# The long-run adstock levels for Solara are:
# - **Google Adstock (\( gads_\infty \))**: 22.31
# - **YouTube Adstock (\( yads_\infty \))**: 40.72
#
# These values match the given expected values in the question.

# %% [markdown]
# #### Question 5)

# %% [markdown]
# #### Question 6)

# %% [markdown]
# 1. **Is the AB-testing procedure important?**
#    - Yes, the AB-testing procedure is crucial in this context. AB-testing allows for a controlled experiment where one group (the "A" group) receives the existing advertising budget, while the other group (the "B" group) receives the increased budget (i.e., the impulse). This setup isolates the effect of the additional advertising expenditure, ensuring that the observed changes in sales can be attributed directly to the increased budget rather than to other factors that might simultaneously influence sales.
#
# 2. **Concerns about Simultaneity and Endogeneity Without AB-Testing**
#    - **Simultaneity Issues:** In the absence of AB-testing, simultaneity can arise when advertising budgets and sales are determined simultaneously. For example, if the advertising budget is adjusted based on observed sales trends, this creates a two-way relationship where sales influence the advertising budget and the advertising budget influences sales. Such a scenario would introduce simultaneity bias, making it difficult to separate the cause-and-effect relationship.
#    - **Endogeneity of Regressors:** Without AB-testing, the advertising budget (as an independent variable) may be endogenous. Endogeneity occurs when the independent variable is correlated with the error term in the regression model, often due to omitted variables, measurement errors, or simultaneity. In this case, if the decision to increase the advertising budget is related to unobserved factors that also affect sales, then the adstock variables (Google and YouTube) would be endogenous. This could bias the estimation of the coefficients \( \phi_g \) and \( \phi_y \), leading to unreliable results.
#
# 3. **Impact on the Interpretation of the Results**
#    - **Bias in Estimated Coefficients:** If simultaneity and endogeneity are present, the estimated coefficients for the adstock variables (\( \phi_g \) and \( \phi_y \)) would be biased and inconsistent. This means that the estimated effect of an additional 100 euros spent on advertising would not accurately reflect the true causal impact on sales.
#    - **Causal Inference Challenges:** The main goal of the impulse response analysis is to understand the causal effect of changes in the advertising budget on sales. Without AB-testing, any observed relationship between advertising expenditure and sales may reflect reverse causality or omitted variables, making it challenging to draw meaningful causal conclusions.
#
# ### Conclusion
# The AB-testing procedure is essential for ensuring the validity of the causal interpretation in this case study. It helps to avoid simultaneity and endogeneity issues by isolating the effect of the advertising budget increase. Without it, the reliability of the model’s results would be compromised, leading to potentially misleading conclusions about the impact of advertising on sales.
