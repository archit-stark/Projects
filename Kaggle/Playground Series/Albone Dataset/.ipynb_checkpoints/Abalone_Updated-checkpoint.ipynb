# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols
import time
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")


def RMSLE(y_predicted, y_true):
    """
    Calculate the expression:
    sqrt(mean((log(1 + y_predicted) - log(1 + y_true)) ** 2))
    """
    y_predicted = np.array(y_predicted)
    y_true = np.array(y_true)

    # Calculate the expression
    expression_result = np.sqrt(np.mean((np.log(1 + y_predicted) - np.log(1 + y_true)) ** 2))
    
    return expression_result

# %%
train = pd.read_csv(r'C:\Users\archi\OneDrive\Desktop\Python Projects\Albone Dataset\train.csv')

# %%
train.columns = ['id', 'Sex', 'Length', 'Diameter', 'Height', 'Total_W', 'Meat_W', 'Gut_W', 'Shell_W', 'Rings']

# %%
train.head()
# Out:
#    id Sex  Length  Diameter  Height  Total_W  Meat_W   Gut_W  Shell_W  Rings
# 0   0   F   0.550     0.430   0.150   0.7715  0.3285  0.1465   0.2400     11
# 1   1   F   0.630     0.490   0.145   1.1300  0.4580  0.2765   0.3200     11
# 2   2   I   0.160     0.110   0.025   0.0210  0.0055  0.0030   0.0050      6
# 3   3   M   0.595     0.475   0.150   0.9145  0.3755  0.2055   0.2500     10
# 4   4   I   0.555     0.425   0.130   0.7820  0.3695  0.1600   0.1975      9

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Actual Total weight

# %%
train['Actual_W'] = train['Meat_W'] + train['Gut_W'] + train['Shell_W']
train.head()
# Out:
#    id Sex  Length  Diameter  Height  Total_W  Meat_W   Gut_W  Shell_W  Rings  \
# 0   0   F   0.550     0.430   0.150   0.7715  0.3285  0.1465   0.2400     11
# 1   1   F   0.630     0.490   0.145   1.1300  0.4580  0.2765   0.3200     11
# 2   2   I   0.160     0.110   0.025   0.0210  0.0055  0.0030   0.0050      6
# 3   3   M   0.595     0.475   0.150   0.9145  0.3755  0.2055   0.2500     10
# 4   4   I   0.555     0.425   0.130   0.7820  0.3695  0.1600   0.1975      9
#
#    Actual_W
# 0    0.7150
# 1    1.0545
# 2    0.0135
# 3    0.8310
# 4    0.7270

# %%
train = train.drop(['Total_W'], axis = 1)

# %%
train.head()
# Out:
#    id Sex  Length  Diameter  Height  Meat_W   Gut_W  Shell_W  Rings  Actual_W
# 0   0   F   0.550     0.430   0.150  0.3285  0.1465   0.2400     11    0.7150
# 1   1   F   0.630     0.490   0.145  0.4580  0.2765   0.3200     11    1.0545
# 2   2   I   0.160     0.110   0.025  0.0055  0.0030   0.0050      6    0.0135
# 3   3   M   0.595     0.475   0.150  0.3755  0.2055   0.2500     10    0.8310
# 4   4   I   0.555     0.425   0.130  0.3695  0.1600   0.1975      9    0.7270

# %%
#For male
male = train[train['Sex'] == 'M'].copy()

#For female
female = train[train['Sex'] == 'F'].copy()

#For Infant
infant = train[train['Sex'] == 'I'].copy()

# %%
sns.boxplot(x='Sex', y='Actual_W', data=train)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Actual_W'>

# %%
train['Is_Adult'] = np.where(train['Sex'] == 'I', 0, 1)

# %% [markdown]
# #### We will create a columns Infant or Adult

# %%
train = train.drop(['Sex'], axis = 1)

# %%
train
# Out:
#           id  Length  Diameter  Height  Meat_W   Gut_W  Shell_W  Rings  \
# 0          0   0.550     0.430   0.150  0.3285  0.1465   0.2400     11
# 1          1   0.630     0.490   0.145  0.4580  0.2765   0.3200     11
# 2          2   0.160     0.110   0.025  0.0055  0.0030   0.0050      6
# 3          3   0.595     0.475   0.150  0.3755  0.2055   0.2500     10
# 4          4   0.555     0.425   0.130  0.3695  0.1600   0.1975      9
# ...      ...     ...       ...     ...     ...     ...      ...    ...
# 90610  90610   0.335     0.235   0.075  0.0685  0.0370   0.0450      6
# 90611  90611   0.555     0.425   0.150  0.3865  0.1815   0.2400      9
# 90612  90612   0.435     0.330   0.095  0.1510  0.0785   0.0815      6
# 90613  90613   0.345     0.270   0.075  0.0980  0.0490   0.0700      6
# 90614  90614   0.425     0.325   0.100  0.1525  0.0785   0.1050      8
#
#        Actual_W  Is_Adult
# 0        0.7150         1
# 1        1.0545         1
# 2        0.0135         0
# ...

# %%
def categorize_number(num):
    if num <= 9:
        return 'small'
    elif 10 <= num <= 18:
        return 'medium'
    else:
        return 'large'
    
    
train['Ring_Cat'] = train['Rings'].apply(categorize_number)

train
# Out:
#           id  Length  Diameter  Height  Meat_W   Gut_W  Shell_W  Rings  \
# 0          0   0.550     0.430   0.150  0.3285  0.1465   0.2400     11
# 1          1   0.630     0.490   0.145  0.4580  0.2765   0.3200     11
# 2          2   0.160     0.110   0.025  0.0055  0.0030   0.0050      6
# 3          3   0.595     0.475   0.150  0.3755  0.2055   0.2500     10
# 4          4   0.555     0.425   0.130  0.3695  0.1600   0.1975      9
# ...      ...     ...       ...     ...     ...     ...      ...    ...
# 90610  90610   0.335     0.235   0.075  0.0685  0.0370   0.0450      6
# 90611  90611   0.555     0.425   0.150  0.3865  0.1815   0.2400      9
# 90612  90612   0.435     0.330   0.095  0.1510  0.0785   0.0815      6
# 90613  90613   0.345     0.270   0.075  0.0980  0.0490   0.0700      6
# 90614  90614   0.425     0.325   0.100  0.1525  0.0785   0.1050      8
#
#        Actual_W  Is_Adult Ring_Cat
# 0        0.7150         1   medium
# 1        1.0545         1   medium
# ...

# %%
train.head()
# Out:
#    id  Length  Diameter  Height  Meat_W   Gut_W  Shell_W  Rings  Actual_W  \
# 0   0   0.550     0.430   0.150  0.3285  0.1465   0.2400     11    0.7150
# 1   1   0.630     0.490   0.145  0.4580  0.2765   0.3200     11    1.0545
# 2   2   0.160     0.110   0.025  0.0055  0.0030   0.0050      6    0.0135
# 3   3   0.595     0.475   0.150  0.3755  0.2055   0.2500     10    0.8310
# 4   4   0.555     0.425   0.130  0.3695  0.1600   0.1975      9    0.7270
#
#    Is_Adult Ring_Cat
# 0         1   medium
# 1         1   medium
# 2         0    small
# 3         1   medium
# 4         0    small

# %%
train = train.drop('id', axis = 1)

# %%
train
# Out:
#        Length  Diameter  Height  Meat_W   Gut_W  Shell_W  Rings  Actual_W  \
# 0       0.550     0.430   0.150  0.3285  0.1465   0.2400     11    0.7150
# 1       0.630     0.490   0.145  0.4580  0.2765   0.3200     11    1.0545
# 2       0.160     0.110   0.025  0.0055  0.0030   0.0050      6    0.0135
# 3       0.595     0.475   0.150  0.3755  0.2055   0.2500     10    0.8310
# 4       0.555     0.425   0.130  0.3695  0.1600   0.1975      9    0.7270
# ...       ...       ...     ...     ...     ...      ...    ...       ...
# 90610   0.335     0.235   0.075  0.0685  0.0370   0.0450      6    0.1505
# 90611   0.555     0.425   0.150  0.3865  0.1815   0.2400      9    0.8080
# 90612   0.435     0.330   0.095  0.1510  0.0785   0.0815      6    0.3110
# 90613   0.345     0.270   0.075  0.0980  0.0490   0.0700      6    0.2170
# 90614   0.425     0.325   0.100  0.1525  0.0785   0.1050      8    0.3360
#
#        Is_Adult Ring_Cat
# 0             1   medium
# 1             1   medium
# ...

# %%
l = list(train.columns)
l.pop(6)
# Out:
# 'Rings'

# %%
for i in l:
    sns.scatterplot(x = 'Rings', y=i, data = train)
    plt.ylabel(i)
    plt.xlabel('Rings')
    plt.show()

# %% [markdown]
# #### I used ChatGPT to explore different features I could come up with

# %%
# 1. Volume
train['Volume'] = (4/3) * np.pi * (train['Length'] * (train['Diameter']/2)**2)

# 2. Shell Surface Area (Approximation)
train['Shell_Surface_Area'] = 4 * np.pi * (train['Diameter']/2) * train['Height']

# 3. Shell Thickness
train['Shell_Thickness'] = train['Actual_W'] - (train['Meat_W'] + train['Gut_W'])

# 4. Shell Density
train['Shell_Density'] = train['Shell_W'] / train['Volume']

# 5. Body Condition Index (BCI)
train['BCI'] = (train['Meat_W'] + train['Gut_W']) / train['Length']

# 6. Ratio of Shell to Soft Tissue
train['Shell_to_Soft_Tissue_Ratio'] = train['Shell_W'] / (train['Meat_W'] + train['Gut_W'])

# 7. Aspect Ratio
train['Aspect_Ratio'] = train['Length'] / train['Diameter']

# 8. Meat to Shell Ratio
train['Meat_to_Shell_Ratio'] = train['Meat_W'] / train['Shell_W']

# 9. Body Shape Index (BSI)
train['BSI'] = train['Length'] / (train['Diameter'] + train['Height'])

# 10. Meat Yield
train['Meat_Yield'] = train['Meat_W'] / (train['Actual_W'])

# 11. Gut Fullness
train['Gut_Fullness'] = train['Gut_W'] / (train['Actual_W'])

# 12. Condition Factor
train['Condition_Factor'] = (train['Actual_W']) / (train['Length']**3)

# 13. Shell Shape Index (Customize as needed)
#train['Shell_Shape_Index'] = train['Length'] / (train['Diameter'] * train['Height'])

# 14. Weight Ratios (Customize as needed)
train['Meat_to_Gut_Ratio'] = train['Meat_W'] / train['Gut_W']

# 15. Surface-to-Volume Ratio
train['Surface_to_Volume_Ratio'] = (train['Shell_Surface_Area'] / train['Volume'])
train = train.drop('Ring_Cat', axis = 1)

# %%
cols = list(train.columns)
cols.pop(6)
# Out:
# 'Rings'

# %%
train_x = train[cols].copy()

# %% [markdown]
# #### Creating Polynomial Features

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2, include_bias=False)

train_poly = poly.fit_transform(train_x)

# Get the names of the new polynomial features
feature_names_poly = poly.get_feature_names(cols)

# %%
train_x = pd.DataFrame(train_poly, columns = feature_names_poly)

# %%
new_list = []
for x in list(train_x.columns):
    x = x.replace(" ","_times_")
    x = x.replace("^", "_")
    new_list.append(x)
    
train_x.columns = new_list
train_x.head()
# Out:
#    Length  Diameter  Height  Meat_W   Gut_W  Shell_W  Actual_W  Is_Adult  \
# 0   0.550     0.430   0.150  0.3285  0.1465   0.2400    0.7150       1.0
# 1   0.630     0.490   0.145  0.4580  0.2765   0.3200    1.0545       1.0
# 2   0.160     0.110   0.025  0.0055  0.0030   0.0050    0.0135       0.0
# 3   0.595     0.475   0.150  0.3755  0.2055   0.2500    0.8310       1.0
# 4   0.555     0.425   0.130  0.3695  0.1600   0.1975    0.7270       0.0
#
#      Volume  Shell_Surface_Area  ...  Gut_Fullness_2  \
# 0  0.106495            0.405265  ...        0.041982
# 1  0.158402            0.446420  ...        0.068754
# 2  0.002027            0.017279  ...        0.049383
# 3  0.140583            0.447677  ...        0.061154
# 4  0.104978            0.347146  ...        0.048436
#
#    Gut_Fullness_times_Condition_Factor  Gut_Fullness_times_Meat_to_Gut_Ratio  \
# 0                             0.880541                              0.459441
# ...

# %%
for x in list(train_x.columns):
    plt.figure(figsize=(3.7,3.7))
    train[x].hist(color = 'green')
    plt.title(x)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Length_2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
list(train_x.columns)
# Out:
# ['Length',
#  'Diameter',
#  'Height',
#  'Meat_W',
#  'Gut_W',
#  'Shell_W',
#  'Actual_W',
#  'Is_Adult',
#  'Volume',
#  'Shell_Surface_Area',
#  'Shell_Thickness',
#  'Shell_Density',
#  'BCI',
#  'Shell_to_Soft_Tissue_Ratio',
#  'Aspect_Ratio',
#  'Meat_to_Shell_Ratio',
#  'BSI',
#  'Meat_Yield',
#  'Gut_Fullness',
#  'Condition_Factor',
#  'Meat_to_Gut_Ratio',
#  'Surface_to_Volume_Ratio',
#  'Length^2',
#  'Length Diameter',
#  'Length Height',
#  'Length Meat_W',
#  'Length Gut_W',
#  'Length Shell_W',
#  'Length Actual_W',
#  'Length Is_Adult',
#  'Length Volume',
#  'Length Shell_Surface_Area',
#  'Length Shell_Thickness',
#  'Length Shell_Density',
#  'Length BCI',
#  'Length Shell_to_Soft_Tissue_Ratio',
#  'Length Aspect_Ratio',
#  'Length Meat_to_Shell_Ratio',
#  'Length BSI',
#  'Length Meat_Yield',
#  'Length Gut_Fullness',
#  'Length Condition_Factor',
#  'Length Meat_to_Gut_Ratio',
#  'Length Surface_to_Volume_Ratio',
#  'Diameter^2',
#  'Diameter Height',
# ...

# %%
new_list = []
for x in list(train_x.columns):
    x = x.replace(" ","_times_")
    x = x.replace("^", "_")
    new_list.append(x)

# %%
new_list
# Out:
# ['Length',
#  'Diameter',
#  'Height',
#  'Meat_W',
#  'Gut_W',
#  'Shell_W',
#  'Actual_W',
#  'Is_Adult',
#  'Volume',
#  'Shell_Surface_Area',
#  'Shell_Thickness',
#  'Shell_Density',
#  'BCI',
#  'Shell_to_Soft_Tissue_Ratio',
#  'Aspect_Ratio',
#  'Meat_to_Shell_Ratio',
#  'BSI',
#  'Meat_Yield',
#  'Gut_Fullness',
#  'Condition_Factor',
#  'Meat_to_Gut_Ratio',
#  'Surface_to_Volume_Ratio',
#  'Length_2',
#  'Length_times_Diameter',
#  'Length_times_Height',
#  'Length_times_Meat_W',
#  'Length_times_Gut_W',
#  'Length_times_Shell_W',
#  'Length_times_Actual_W',
#  'Length_times_Is_Adult',
#  'Length_times_Volume',
#  'Length_times_Shell_Surface_Area',
#  'Length_times_Shell_Thickness',
#  'Length_times_Shell_Density',
#  'Length_times_BCI',
#  'Length_times_Shell_to_Soft_Tissue_Ratio',
#  'Length_times_Aspect_Ratio',
#  'Length_times_Meat_to_Shell_Ratio',
#  'Length_times_BSI',
#  'Length_times_Meat_Yield',
#  'Length_times_Gut_Fullness',
#  'Length_times_Condition_Factor',
# ...

# %%
# Out:
# Length^2

# %%
# Out:
# 'Rings'

# %%
for l in l:
    train[l].hist(bins = 30)
    plt.title(l)
    plt.show()

# %%
l
# Out:
# 'Surface_to_Volume_Ratio'

# %%
l = list(train.columns)
l.pop(6)
for l in l:
    sns.scatterplot(x = 'Rings', y=i, data = train, color = 'red')
    plt.ylabel(i)
    plt.xlabel('Rings')
    plt.show()

# %%
l = list(train.columns)

# %%
l.pop(6)
# Out:
# 'Rings'

# %%
for l in l:
    sns.scatterplot(x = 'Rings', y=l, data = train, color = 'red')
    plt.ylabel(l)
    plt.xlabel('Rings')
    plt.show()

# %%
train_2 = train.copy()

# %%
cols = list(train_2.columns)
cols.pop(6)
cols.pop(7)
# Out:
# 'Is_Adult'

# %%
train_2 = train_2[train_2['Shell_Density'] < 7]
train_2 = train_2[train_2['Height'] < 0.3]
train_2 = train_2[train_2['Shell_to_Soft_Tissue_Ratio'] < 1.22]
train_2 = train_2[train_2['Aspect_Ratio'] < 2.1]
train_2 = train_2[train_2['Aspect_Ratio'] > 0.75]
train_2 = train_2[train_2['Meat_to_Shell_Ratio'] < 5.2]
train_2 = train_2[train_2['BSI'] < 1.7]
train_2 = train_2[train_2['Meat_Yield'] < 0.8]
train_2 = train_2[train_2['Gut_Fullness'] < 0.5]
train_2 = train_2[train_2['Condition_Factor'] < 13]
train_2 = train_2[train_2['Shell_Shape_Index'] <= 125]
train_2 = train_2[train_2['Meat_to_Gut_Ratio'] < 6.3]
train_2 = train_2[train_2['Surface_to_Volume_Ratio'] < 21]

# %%
train_2 = np.log1p(train_2[cols])

# %%
for x in cols:
    train_2[x].hist(bins = 30, color ='green')
    plt.title(x)
    plt.show()

# %%
train_2 = np.log1p(train_2[cols])
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
train_2 = scaler.fit_transform(train_2)
train_2 = pd.DataFrame(train_2, columns=cols)

# %%
train_2 = pd.concat([train_2, train[['Rings', 'Is_Adult']]], axis = 1)

# %%
train_2
# Out:
#          Length  Diameter    Height    Meat_W     Gut_W   Shell_W  Actual_W  \
# 0      0.304917  0.312807  0.396699  0.014040 -0.189468  0.161888  0.072782
# 1      0.927699  0.883007  0.266542  0.635852  1.071465  0.758141  0.803221
# 2     -3.281847 -3.201402 -3.040558 -1.848188 -1.759272 -1.842050 -2.054416
# 3      0.659080  0.742639  0.396699  0.246458  0.399634  0.238490  0.337464
# 4      0.344772  0.264215 -0.127370  0.217234 -0.052041 -0.170716  0.100981
# ...         ...       ...       ...       ...       ...       ...       ...
# 90610 -1.542993 -1.721010 -1.617852 -1.441931 -1.367915 -1.469830 -1.541680
# 90611  0.344772  0.264215  0.396699  0.299707  0.163555  0.161888  0.286343
# 90612 -0.649088 -0.692917 -1.067215 -0.944727 -0.907260 -1.142407 -1.013549
# 90613 -1.450640 -1.333319 -1.617852 -1.259866 -1.232845 -1.244360 -1.314434
# 90614 -0.735628 -0.745169 -0.931127 -0.936021 -0.907260 -0.937397 -0.937157
#
# ...

# %%
cols.append('Is_Adult')

# %% [markdown]
# #### KNN

# %%
#x = train_2[['Length', 'Diameter', 'Is_Adult', 'Actual_W']]
x = train_2[cols]
#x = train_2[['Length', 'Diameter' ,'Height', 'Meat_W', 'Shell_W']]
y = train_2[['Rings']]
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state = 42)

# %%
model = KNeighborsRegressor(60)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(RMSLE(y_test, y_pred))
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# 0.15699936644433352
# Mean Squared Error: 3.740432308239377

# %%
from sklearn.metrics import mean_absolute_error

# Assuming y_true and y_pred are the true and predicted target values, respectively
mae = mean_absolute_error(y_test, y_pred)

print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 1.2961623351542237

# %% [markdown]
# #### XGBoost

# %%
model = XGBRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(RMSLE(y_test, y_pred))
# Out:
# 0.3790889981557219

# %%
from sklearn.metrics import mean_absolute_error

# Assuming y_true and y_pred are the true and predicted target values, respectively
mae = mean_absolute_error(y_test, y_pred)

print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 1.2995908097216264

# %%
from sklearn.ensemble import RandomForestRegressor
rf_regressor = RandomForestRegressor(random_state=42)

rf_regressor.fit(X_train, y_train)

# Make predictions on the testing data
y_pred = rf_regressor.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 3.8296592641153198

# %%
print(RMSLE(y_test, y_pred))
# Out:
# 0.3810680659586794

# %%
d = {}
for i in range(1,60):
    print(i)
    model = KNeighborsRegressor(i)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    d[i] = RMSLE(y_test, y_pred)
    
g = pd.DataFrame(d)
g = g.transpose()

plt.xticks()
plt.plot(g)
plt.show()
# Out:
# 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18240\2184742895.py in <module>
#       4     model = KNeighborsRegressor(i)
#       5     model.fit(X_train, y_train)
# ----> 6     y_pred = model.predict(X_test)
#       7     d[i] = RMSLE(y_test, y_pred)
#       8
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_regression.py in predict(self, X)
#     227             Target values.
#     228         """
# --> 229         neigh_dist, neigh_ind = self.kneighbors(X)
#     230
#     231         weights = _get_weights(neigh_dist, self.weights)
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     750                 kwds = self.effective_metric_params_
#     751
# --> 752             chunked_results = list(
#     753                 pairwise_distances_chunked(
# ...

# %%
g = pd.DataFrame(pd.Series(d), index = d.keys(), columns = ['RMSE'])

# %%
# Out:
# <AxesSubplot:>

# %%
start_time = time.time()

import matplotlib.pyplot as plt
from sklearn.inspection import permutation_importance

# Assuming X_train and y_train are your training data

# Calculate permutation importance
perm_importance = permutation_importance(model, X_train, y_train)

# Get feature importances
feature_importance = perm_importance.importances_mean

# Sort features by importance
sorted_indices = np.argsort(feature_importance)[::-1]
sorted_features = X_train.columns[sorted_indices]
sorted_importances = feature_importance[sorted_indices]

# Plot sorted feature importances
plt.figure(figsize=(10, 6))
plt.barh(range(len(sorted_features)), sorted_importances, align='center')
plt.yticks(range(len(sorted_features)), sorted_features)
plt.xlabel('Permutation Importance')
plt.title('Feature Importances')
plt.show()

end_time = time.time()
elapsed_time = end_time - start_time

print("Time taken:", elapsed_time, "seconds")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18240\3351011959.py in <module>
#       7
#       8 # Calculate permutation importance
# ----> 9 perm_importance = permutation_importance(model, X_train, y_train)
#      10
#      11 # Get feature importances
#
# ~\anaconda3\lib\site-packages\sklearn\inspection\_permutation_importance.py in permutation_importance(estimator, X, y, scoring, n_repeats, n_jobs, random_state, sample_weight, max_samples)
#     257     baseline_score = _weights_scorer(scorer, estimator, X, y, sample_weight)
#     258
# --> 259     scores = Parallel(n_jobs=n_jobs)(
#     260         delayed(_calculate_permutation_scores)(
#     261             estimator,
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# ...

# %%
test_df = pd.read_csv(r'C:\Users\archi\OneDrive\Desktop\Python Projects\Albone Dataset\test.csv')
test_df.columns = ['id', 'Sex', 'Length', 'Diameter', 'Height', 'Total_W', 'Meat_W', 'Gut_W', 'Shell_W']
test_df['Actual_W'] = test_df['Meat_W'] + test_df['Gut_W'] + test_df['Shell_W']
test_df['Is_Adult'] = np.where(test_df['Sex'] == 'I', 0, 1)
# 1. Volume
test_df['Volume'] = (4/3) * np.pi * (test_df['Length'] * (test_df['Diameter']/2)**2)

# 2. Shell Surface Area (Approximation)
test_df['Shell_Surface_Area'] = 4 * np.pi * (test_df['Diameter']/2) * test_df['Height']

# 3. Shell Thickness
test_df['Shell_Thickness'] = test_df['Actual_W'] - (test_df['Meat_W'] + test_df['Gut_W'])

# 4. Shell Density
test_df['Shell_Density'] = test_df['Shell_W'] / test_df['Volume']

# 5. Body Condition Index (BCI)
test_df['BCI'] = (test_df['Meat_W'] + test_df['Gut_W']) / test_df['Length']

# 6. Ratio of Shell to Soft Tissue
test_df['Shell_to_Soft_Tissue_Ratio'] = test_df['Shell_W'] / (test_df['Meat_W'] + test_df['Gut_W'])

# 7. Aspect Ratio
test_df['Aspect_Ratio'] = test_df['Length'] / test_df['Diameter']

# 8. Meat to Shell Ratio
test_df['Meat_to_Shell_Ratio'] = test_df['Meat_W'] / test_df['Shell_W']

# 9. Body Shape Index (BSI)
test_df['BSI'] = test_df['Length'] / (test_df['Diameter'] + test_df['Height'])

# 10. Meat Yield
test_df['Meat_Yield'] = test_df['Meat_W'] / (test_df['Actual_W'])

# 11. Gut Fullness
test_df['Gut_Fullness'] = test_df['Gut_W'] / (test_df['Actual_W'])

# 12. Condition Factor
test_df['Condition_Factor'] = (test_df['Actual_W']) / (test_df['Length']**3)

# 13. Shell Shape Index (Customize as needed)
#test_df['Shell_Shape_Index'] = test_df['Length'] / (test_df['Diameter'] * test_df['Height'])

# 14. Weight Ratios (Customize as needed)
test_df['Meat_to_Gut_Ratio'] = test_df['Meat_W'] / test_df['Gut_W']

# 15. Surface-to-Volume Ratio
test_df['Surface_to_Volume_Ratio'] = (test_df['Shell_Surface_Area'] / test_df['Volume'])

# %%
test_df = test_df.drop(['Sex', 'id', 'Total_W'], axis = 1)

# %%
cols_2 = list(test_df.columns)
cols_2.pop(7)
# Out:
# 'Is_Adult'

# %%
test_df.columns
# Out:
# Index(['Length', 'Diameter', 'Height', 'Meat_W', 'Gut_W', 'Shell_W',
#        'Actual_W', 'Is_Adult', 'Volume', 'Shell_Surface_Area',
#        'Shell_Thickness', 'Shell_Density', 'BCI', 'Shell_to_Soft_Tissue_Ratio',
#        'Aspect_Ratio', 'Meat_to_Shell_Ratio', 'BSI', 'Meat_Yield',
#        'Gut_Fullness', 'Condition_Factor', 'Meat_to_Gut_Ratio',
#        'Surface_to_Volume_Ratio'],
#       dtype='object')

# %%
test_df_2 = test_df.copy()

# %%
cols = test_df_2

# %%
test_df_2 = np.log1p(test_df_2[cols_2])
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
test_df_2 = scaler.fit_transform(test_df_2)
test_df_2 = pd.DataFrame(test_df_2, columns=cols_2)

# %%
# Out:
# 22

# %%
test_df = pd.concat([test_df_2, test_df['Is_Adult']],axis = 1)

# %%
len(test_df.columns)
# Out:
# 23

# %%
test_df['Rings'] = model.predict(test_df)

# %%
id = pd.read_csv(r'C:\Users\archi\OneDrive\Desktop\Python Projects\Albone Dataset\test.csv')

# %%
id = id['id']

# %%
final = pd.concat([id , test_df['Rings']], axis = 1)

# %%
final.to_csv('res_5.csv', index = False)

# %%
len(final)
# Out:
# 60411
